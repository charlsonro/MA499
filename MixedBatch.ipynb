# %%
import numpy as np
import os
import random
from random import shuffle
import scipy.misc
import scipy
import time
import skimage.io
from skimage.io import imread
import keras
import keras.callbacks
from keras import optimizers, metrics, regularizers
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, SeparableConv2D, core
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Cropping2D, concatenate, Input
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.activations import softmax
import matplotlib
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix

class_weight_one = 1
class_weight_two = 1
batch_size = 2
epochs_2_train = 10
validPercent = 0.1
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
label_folder = '/data/Ro_ImageData/32xOTSU/' #Otsu images
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions/' #Folder for predictions

def get_sample(sample,image_folder,label_folder):
    inputImg = sample
    maskImg = sample.split('_C')[0] + '.tiff'
    img_int = np.array(imread(image_folder + inputImg), dtype = 'float32')/255
    lbl_int = np.array(imread(label_folder + maskImg), dtype = 'float32')/2**16
    lbl_int[:,:,1] = 1-lbl_int[:,:,0]
    lbl_int = lbl_int[:,:,0:2]
    return img_int,lbl_int

def get_sample_test(sample,test_folder):
    img_int = np.array(imread(test_folder + sample), dtype = 'float32')/255
    return img_int

def data_generator(file_name_list,batch_size): #randomly sampled instances from file name list with batch size
    while True:
        batch_filenames = np.random.choice(file_name_list,batch_size)
        batch_input = []
        batch_output = []
        for i_filename in batch_filenames:
            Ai_img, Ai_mask = get_sample(i_filename,image_folder,label_folder)
            batch_input += [Ai_img]
            batch_output += [Ai_mask]
            #print(i_filename)
        batch_img = np.expand_dims(np.array(batch_input,dtype='float32'),axis=-1)
        batch_mask = np.array(batch_output,dtype='float32')
        yield (batch_img,batch_mask)

def Weighted_Binary_CrossEntropy(y_true_n,y_pred_n):
    b_ce = K.binary_crossentropy(y_true_n,y_pred_n)
    y_true = K.cast(K.expand_dims(K.argmax(y_true_n,axis=-1),axis=-1),dtype='float32')
    y_pred = K.cast(K.expand_dims(K.argmax(y_pred_n,axis=-1),axis=-1),dtype='float32')
    #Pixel Disparity
    one_weight = class_weight_one
    zero_weight = class_weight_two
    weight_vector = y_true * one_weight + (1.-y_true)*zero_weight
    weighted_b_ce = weight_vector*b_ce
    return K.mean(weighted_b_ce)

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    highSN = os.listdir(highSN_folder)
    highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = np.random.choice(highSN,sampleSize-int(sampleSize*prop))
    lowSample = np.random.choice(lowSN,int(sampleSize*prop))
    sampleList = highSample + lowSample
    for file in sampleList:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.025)

indexes_valid = random.sample(range(0,len(sampleList)),int(validPercent*float(len(sampleList))))
indexes_train = [x for x in range(0,len(sampleList)) if x not in indexes_valid]
training_list = [x for ind,x in enumerate(sampleList) if ind in indexes_train]
valid_list = [x for ind,x in enumerate(sampleList) if ind in indexes_valid]
#(batch1,batch2) = data_generator(training_list,batch_size)
#print(batch1.shape)
#print(batch2.shape)

'''

test1,test2 = get_sample(training_list[0])
print(np.max(test2))
print(np.min(test2))
matplotlib.image.imsave('test1.png',test1)
matplotlib.image.imsave('test2.png',test2)

'''
num_train_calls = int(float(len(training_list)+1)/float(batch_size))
num_valid_calls = int(float(len(valid_list)+1)/float(batch_size))

#### Network is built ####
network = Sequential()
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),input_shape = (1024,1024,1),
padding = 'same'))
network.add(keras.layers.BatchNormalization())
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(2,(1,1),activation = 'softmax',kernel_regularizer = regularizers.l2(.01),padding='same'))
sgd = optimizers.SGD(lr = 0.0001, decay = 1e-8, momentum = 0.9, nesterov = False)
network.compile(loss = Weighted_Binary_CrossEntropy, optimizer = sgd, metrics = ['accuracy'])
network.summary()
#network.load_weights('weights.h5')
network_training = network.fit_generator(data_generator(training_list,batch_size),
steps_per_epoch = 50, epochs = epochs_2_train, verbose = 1,validation_data = 
data_generator(valid_list,batch_size),validation_steps = num_valid_calls)
#network.save_weights('weights.h5')
TP = 0 #True Positives
TN = 0 #True Negatives
FP = 0 #False Positives
FN = 0 #False Negatives

for filename in valid_list: #Use for new lists
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    TP += np.sum(pred*lbl,dtype='float32')
    TN += np.sum((1-pred)*(1-lbl),dtype='float32')
    FP += np.sum((1-pred)*lbl,dtype='float32')
    FN += np.sum(pred*(1-lbl),dtype='float32')

ACC = (TP + TN)/(TP + TN + FP + FN) #Accuracy
Recall = (TP)/(TP + FN)
Precision = (TP)/(TP + FP)
MCC = ((TP * TN) - (FP * FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

np.savetxt('ValidationMetrics2.txt',(ACC,Recall,Precision,MCC))
np.savetxt('ValidationLoss2.txt',network_training.history['val_loss'])
np.savetxt('ValidationAcc2.txt',network_training.history['val_accuracy'])

'''
plt.plot([1,2])
plt.ylabel(network_training.history['val_acc'])
plt.show()
'''

test_list = valid_list
'''
### Generate predictions from trained model ###
for filename in test_list:
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)
'''
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-3-8a4aa0743c30> in <module>
#      92     return sampleList
#      93
# ---> 94 sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.025)
#      95
#      96 indexes_valid = random.sample(range(0,len(sampleList)),int(validPercent*float(len(sampleList))))
#
# <ipython-input-3-8a4aa0743c30> in makeSampleList(highSN_folder, lowSN_folder, sampleSize, prop)
#      86     highSample = np.random.choice(highSN,sampleSize-int(sampleSize*prop))
#      87     lowSample = np.random.choice(lowSN,int(sampleSize*prop))
# ---> 88     sampleList = highSample + lowSample
#      89     for file in sampleList:
#      90         if os.path.splitext(file)[1] == '.tiff':
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U68'), dtype('<U68')) -> dtype('<U68')

# %%
prediction_folder = '/home/dspuser/MA499/Predictions/' #Folder for predictions
test_list = valid_list
for filename in test_list:
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)

# %%
img_pred
# Out:
# array([[[[4.08953913e-02, 9.59104598e-01],
#          [2.86899805e-01, 7.13100255e-01],
#          [2.55960273e-04, 9.99743998e-01],
#          ...,
#          [5.55715133e-07, 9.99999404e-01],
#          [2.59438650e-07, 9.99999762e-01],
#          [1.01332866e-01, 8.98667097e-01]],
#
#         [[1.43952379e-02, 9.85604703e-01],
#          [1.61494652e-04, 9.99838471e-01],
#          [3.84293380e-04, 9.99615669e-01],
#          ...,
#          [4.71111089e-02, 9.52888906e-01],
#          [1.61086628e-08, 1.00000000e+00],
#          [4.65085894e-01, 5.34914076e-01]],
#
#         [[9.20047518e-04, 9.99079943e-01],
#          [9.09818470e-01, 9.01815668e-02],
#          [1.36495659e-08, 1.00000000e+00],
#          ...,
#          [2.37011317e-08, 1.00000000e+00],
#          [8.35604386e-09, 1.00000000e+00],
#          [4.16931385e-07, 9.99999642e-01]],
#
#         ...,
#
#         [[8.59623123e-03, 9.91403759e-01],
#          [7.50332233e-03, 9.92496729e-01],
#          [4.41316705e-11, 1.00000000e+00],
#          ...,
#          [8.85718942e-01, 1.14281073e-01],
#          [3.61273110e-01, 6.38726890e-01],
#          [2.51686007e-01, 7.48313963e-01]],
#
#         [[1.11171914e-11, 1.00000000e+00],
#          [4.63819169e-02, 9.53618050e-01],
#          [2.55912650e-24, 1.00000000e+00],
#          ...,
#          [2.14681113e-05, 9.99978542e-01],
#          [4.91014635e-03, 9.95089769e-01],
#          [8.90728272e-03, 9.91092741e-01]],
#
#         [[3.02690609e-07, 9.99999642e-01],
#          [1.56294334e-16, 1.00000000e+00],
#          [8.70737094e-10, 1.00000000e+00],
#          ...,
#          [1.81320909e-04, 9.99818742e-01],
#          [1.22006582e-02, 9.87799287e-01],
#          [9.09577124e-03, 9.90904272e-01]]]], dtype=float32)

# %%
import numpy as np
import os
import random
from random import shuffle
import scipy.misc
import scipy
import time
import skimage.io
from skimage.io import imread
import keras
import keras.callbacks
from keras import optimizers, metrics, regularizers
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, SeparableConv2D, core
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Cropping2D, concatenate, Input
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.activations import softmax
import matplotlib
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix

class_weight_one = 1
class_weight_two = 1
batch_size = 2
epochs_2_train = 10
validPercent = 0.1
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
label_folder = '/data/Ro_ImageData/32xOTSU/' #Otsu images
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions/' #Folder for predictions

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    highSN = os.listdir(highSN_folder)
    highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = list(np.random.choice(highSN,2000-round(2000*0.025)))
    lowSample = list(np.random.choice(lowSN,round(2000*0.025)))
    sampleListAll = highSample + lowSample
    for file in sampleListAll:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.025)

# %%
highSN = os.listdir(highSN_folder)
highSN = [os.path.join(highSN_folder,file) for file in highSN]
lowSN = os.listdir(lowSN_folder)
lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
highSample = list(np.random.choice(highSN,2000-round(2000*0.025)))
lowSample = list(np.random.choice(lowSN,round(2000*0.025)))

# %%
os.path.splitext(sampleList[1])[1]
# Out:
# '.tiff'

# %%
sampleList
# Out:
# ['/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/00Tree.html',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c026.tiff',
# ...
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r019_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c025.tiff',
#  ...]
