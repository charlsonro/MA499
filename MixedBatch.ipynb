# %%
import numpy as np
import os
import random
from random import shuffle
import scipy.misc
import scipy
import time
import skimage.io
from skimage.io import imread
import keras
import keras.callbacks
from keras import optimizers, metrics, regularizers
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, SeparableConv2D, core
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Cropping2D, concatenate, Input
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.activations import softmax
import matplotlib
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix

class_weight_one = 1
class_weight_two = 1
batch_size = 2
epochs_2_train = 10
validPercent = 0.1
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
highSN_label = '/data/Ro_ImageData/32xOTSU/' #Otsu images
lowSN_label = '/data/Ro_ImageData/32xOTSULow'
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions2/' #Folder for predictions

def get_sample(sample, highSN_folder, lowSN_folder, highSN_label, lowSN_label):
    if ('_C' in sample):
    #If it's a low SN image
        inputImgPath = os.path.join(lowSN_folder, sample)
        maskImgPath = os.path.join(lowSN_label, sample)
    else:
    #If it's a high SN image
        inputImgPath = os.path.join(highSN_folder, sample)
        maskImgPath = os.path.join(highSN_label, sample)
    img_int = np.array(imread(inputImgPath), dtype = 'float32')/255
    lbl_int = np.array(imread(maskImgPath), dtype = 'float32')/2**16
    lbl_int[:,:,1] = 1-lbl_int[:,:,0]
    lbl_int = lbl_int[:,:,0:2]
    return img_int,lbl_int

def get_sample_test(sample,test_folder):
    img_int = np.array(imread(test_folder + sample), dtype = 'float32')/255
    return img_int

def data_generator(file_name_list,batch_size): #randomly sampled instances from file name list with batch size
    while True:
        batch_filenames = np.random.choice(file_name_list,batch_size)
        batch_input = []
        batch_output = []
        for i_filename in batch_filenames:
            Ai_img, Ai_mask = get_sample(i_filename,highSN_folder,lowSN_folder,highSN_label,lowSN_label)
            batch_input += [Ai_img]
            batch_output += [Ai_mask]
            #print(i_filename)
        batch_img = np.expand_dims(np.array(batch_input,dtype='float32'),axis=-1)
        batch_mask = np.array(batch_output,dtype='float32')
        yield (batch_img,batch_mask)

def Weighted_Binary_CrossEntropy(y_true_n,y_pred_n):
    b_ce = K.binary_crossentropy(y_true_n,y_pred_n)
    y_true = K.cast(K.expand_dims(K.argmax(y_true_n,axis=-1),axis=-1),dtype='float32')
    y_pred = K.cast(K.expand_dims(K.argmax(y_pred_n,axis=-1),axis=-1),dtype='float32')
    #Pixel Disparity
    one_weight = class_weight_one
    zero_weight = class_weight_two
    weight_vector = y_true * one_weight + (1.-y_true)*zero_weight
    weighted_b_ce = weight_vector*b_ce
    return K.mean(weighted_b_ce)

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    sampleList = []
    highSN = os.listdir(highSN_folder)
    #highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    #lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = list(np.random.choice(highSN,sampleSize-round(sampleSize*prop)))
    lowSample = list(np.random.choice(lowSN,round(sampleSize*prop)))
    sampleListAll = highSample + lowSample
    for file in sampleListAll:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.10)

indexes_valid = random.sample(range(0,len(sampleList)),int(validPercent*float(len(sampleList))))
indexes_train = [x for x in range(0,len(sampleList)) if x not in indexes_valid]
training_list = [x for ind,x in enumerate(sampleList) if ind in indexes_train]
valid_list = [x for ind,x in enumerate(sampleList) if ind in indexes_valid]
#(batch1,batch2) = data_generator(training_list,batch_size)
#print(batch1.shape)
#print(batch2.shape)

'''

test1,test2 = get_sample(training_list[0])
print(np.max(test2))
print(np.min(test2))
matplotlib.image.imsave('test1.png',test1)
matplotlib.image.imsave('test2.png',test2)

'''
num_train_calls = int(float(len(training_list)+1)/float(batch_size))
num_valid_calls = int(float(len(valid_list)+1)/float(batch_size))

#### Network is built ####
network = Sequential()
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),input_shape = (1024,1024,1),
padding = 'same'))
network.add(keras.layers.BatchNormalization())
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(2,(1,1),activation = 'softmax',kernel_regularizer = regularizers.l2(.01),padding='same'))
sgd = optimizers.SGD(lr = 0.0001, decay = 1e-8, momentum = 0.9, nesterov = False)
network.compile(loss = Weighted_Binary_CrossEntropy, optimizer = sgd, metrics = ['accuracy'])
network.summary()
#network.load_weights('weights.h5')
network_training = network.fit_generator(data_generator(training_list,batch_size),steps_per_epoch = 50, 
                                         epochs = epochs_2_train, verbose = 1,validation_data = data_generator(valid_list,batch_size),
                                         validation_steps = num_valid_calls)
#network.save_weights('weights.h5')
TP = 0 #True Positives
TN = 0 #True Negatives
FP = 0 #False Positives
FN = 0 #False Negatives

for filename in valid_list: #Use for new lists
    img,lbl = get_sample(filename,highSN_folder,lowSN_folder,highSN_label,lowSN_label)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    TP += np.sum(pred*lbl,dtype='float32')
    TN += np.sum((1-pred)*(1-lbl),dtype='float32')
    FP += np.sum((1-pred)*lbl,dtype='float32')
    FN += np.sum(pred*(1-lbl),dtype='float32')

ACC = (TP + TN)/(TP + TN + FP + FN) #Accuracy
Recall = (TP)/(TP + FN)
Precision = (TP)/(TP + FP)
MCC = ((TP * TN) - (FP * FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

np.savetxt('ValidationMetrics2.txt',(ACC,Recall,Precision,MCC))
np.savetxt('ValidationLoss2.txt',network_training.history['val_loss'])
np.savetxt('ValidationAcc2.txt',network_training.history['val_accuracy'])

'''
plt.plot([1,2])
plt.ylabel(network_training.history['val_acc'])
plt.show()
'''

test_list = valid_list

### Generate predictions from trained model ###
for filename in test_list:
    img,lbl = get_sample(filename, highSN_folder, lowSN_folder, highSN_label, lowSN_label)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_126 (Conv2D)          (None, 1024, 1024, 10)    100
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 1024, 1024, 10)    40
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_129 (Conv2D)          (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_130 (Conv2D)          (None, 1024, 1024, 2)     22
# =================================================================
# Total params: 3,012
# Trainable params: 2,932
# Non-trainable params: 80
# _________________________________________________________________
# Epoch 1/10
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2616: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2551: UserWarning: unpack: buffer size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# 50/50 [==============================] - 18s 365ms/step - loss: 1.0889 - accuracy: 0.6118 - val_loss: 0.8682 - val_accuracy: 0.6683
# Epoch 2/10
# 50/50 [==============================] - 17s 330ms/step - loss: 0.9420 - accuracy: 0.7416 - val_loss: 1.0179 - val_accuracy: 0.6683
# Epoch 3/10
# 50/50 [==============================] - 17s 340ms/step - loss: 0.8486 - accuracy: 0.8129 - val_loss: 0.8161 - val_accuracy: 0.6695
# Epoch 4/10
# 50/50 [==============================] - 16s 328ms/step - loss: 0.7843 - accuracy: 0.8519 - val_loss: 0.8730 - val_accuracy: 0.6802
# Epoch 5/10
# 50/50 [==============================] - 17s 337ms/step - loss: 0.7487 - accuracy: 0.8604 - val_loss: 0.6879 - val_accuracy: 0.7157
# Epoch 6/10
# 50/50 [==============================] - 17s 330ms/step - loss: 0.6982 - accuracy: 0.8914 - val_loss: 0.5717 - val_accuracy: 0.8835
# Epoch 7/10
# 50/50 [==============================] - 17s 331ms/step - loss: 0.6896 - accuracy: 0.8942 - val_loss: 0.6694 - val_accuracy: 0.9363
# Epoch 8/10
# 50/50 [==============================] - 17s 332ms/step - loss: 0.6644 - accuracy: 0.8990 - val_loss: 0.6476 - val_accuracy: 0.9394
# Epoch 9/10
# 50/50 [==============================] - 16s 328ms/step - loss: 0.6338 - accuracy: 0.9172 - val_loss: 0.4941 - val_accuracy: 0.9479
# Epoch 10/10
# 50/50 [==============================] - 16s 330ms/step - loss: 0.5977 - accuracy: 0.9351 - val_loss: 0.7461 - val_accuracy: 0.9298

# %%
import numpy as np
import os
import random
from random import shuffle
import scipy.misc
import scipy
import time
import skimage.io
from skimage.io import imread
import keras
import keras.callbacks
from keras import optimizers, metrics, regularizers
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, SeparableConv2D, core
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Cropping2D, concatenate, Input
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.activations import softmax
import matplotlib
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix

class_weight_one = 1
class_weight_two = 1
batch_size = 2
epochs_2_train = 10
validPercent = 0.1
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
label_folder = '/data/Ro_ImageData/32xOTSU/' #Otsu images
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions2/' #Folder for predictions

def get_sample(sample, highSN_folder, lowSN_folder,label_folder):
    if ('_C' in sample):
    #If it's a low SN image
        inputImgPath = os.path.join(lowSN_folder, sample)
        maskImg = sample.split('_C')[0] + '.tiff'
    else:
    #If it's a high SN image
        inputImgPath = os.path.join(highSN_folder, sample)
        maskImg = sample
    maskImgPath = os.path.join(label_folder, maskImg)
    img_int = np.array(imread(inputImgPath), dtype = 'float32')/255
    lbl_int = np.array(imread(maskImgPath), dtype = 'float32')/2**16
    lbl_int[:,:,1] = 1-lbl_int[:,:,0]
    lbl_int = lbl_int[:,:,0:2]
    return img_int,lbl_int

def get_sample_test(sample,test_folder):
    img_int = np.array(imread(test_folder + sample), dtype = 'float32')/255
    return img_int

def data_generator(file_name_list,batch_size): #randomly sampled instances from file name list with batch size
    while True:
        batch_filenames = np.random.choice(file_name_list,batch_size)
        batch_input = []
        batch_output = []
        for i_filename in batch_filenames:
            Ai_img, Ai_mask = get_sample(i_filename,highSN_folder,lowSN_folder,label_folder)
            batch_input += [Ai_img]
            batch_output += [Ai_mask]
            #print(i_filename)
        batch_img = np.expand_dims(np.array(batch_input,dtype='float32'),axis=-1)
        batch_mask = np.array(batch_output,dtype='float32')
        yield (batch_img,batch_mask)

def Weighted_Binary_CrossEntropy(y_true_n,y_pred_n):
    b_ce = K.binary_crossentropy(y_true_n,y_pred_n)
    y_true = K.cast(K.expand_dims(K.argmax(y_true_n,axis=-1),axis=-1),dtype='float32')
    y_pred = K.cast(K.expand_dims(K.argmax(y_pred_n,axis=-1),axis=-1),dtype='float32')
    #Pixel Disparity
    one_weight = class_weight_one
    zero_weight = class_weight_two
    weight_vector = y_true * one_weight + (1.-y_true)*zero_weight
    weighted_b_ce = weight_vector*b_ce
    return K.mean(weighted_b_ce)

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    sampleList = []
    highSN = os.listdir(highSN_folder)
    #highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    #lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = list(np.random.choice(highSN,sampleSize-round(sampleSize*prop)))
    lowSample = list(np.random.choice(lowSN,round(sampleSize*prop)))
    sampleListAll = highSample + lowSample
    for file in sampleListAll:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.05)

indexes_valid = random.sample(range(0,len(sampleList)),int(validPercent*float(len(sampleList))))
indexes_train = [x for x in range(0,len(sampleList)) if x not in indexes_valid]
training_list = [x for ind,x in enumerate(sampleList) if ind in indexes_train]
valid_list = [x for ind,x in enumerate(sampleList) if ind in indexes_valid]
#(batch1,batch2) = data_generator(training_list,batch_size)
#print(batch1.shape)
#print(batch2.shape)

'''

test1,test2 = get_sample(training_list[0])
print(np.max(test2))
print(np.min(test2))
matplotlib.image.imsave('test1.png',test1)
matplotlib.image.imsave('test2.png',test2)

'''
num_train_calls = int(float(len(training_list)+1)/float(batch_size))
num_valid_calls = int(float(len(valid_list)+1)/float(batch_size))

#### Network is built ####
network = Sequential()
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),input_shape = (1024,1024,1),
padding = 'same'))
network.add(keras.layers.BatchNormalization())
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(2,(1,1),activation = 'softmax',kernel_regularizer = regularizers.l2(.01),padding='same'))
sgd = optimizers.SGD(lr = 0.0001, decay = 1e-8, momentum = 0.9, nesterov = False)
network.compile(loss = Weighted_Binary_CrossEntropy, optimizer = sgd, metrics = ['accuracy'])
network.summary()
#network.load_weights('weights.h5')
network_training = network.fit_generator(data_generator(training_list,batch_size),steps_per_epoch = 50, 
                                         epochs = epochs_2_train, verbose = 1,validation_data = data_generator(valid_list,batch_size),
                                         validation_steps = num_valid_calls)
#network.save_weights('weights.h5')
TP = 0 #True Positives
TN = 0 #True Negatives
FP = 0 #False Positives
FN = 0 #False Negatives

for filename in valid_list: #Use for new lists
    img,lbl = get_sample(filename,highSN_folder,lowSN_folder,label_folder)
    
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    TP += np.sum(pred*lbl,dtype='float32')
    TN += np.sum((1-pred)*(1-lbl),dtype='float32')
    FP += np.sum((1-pred)*lbl,dtype='float32')
    FN += np.sum(pred*(1-lbl),dtype='float32')

ACC = (TP + TN)/(TP + TN + FP + FN) #Accuracy
Recall = (TP)/(TP + FN)
Precision = (TP)/(TP + FP)
MCC = ((TP * TN) - (FP * FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

np.savetxt('ValidationMetrics2.txt',(ACC,Recall,Precision,MCC))
np.savetxt('ValidationLoss2.txt',network_training.history['val_loss'])
np.savetxt('ValidationAcc2.txt',network_training.history['val_accuracy'])

'''
plt.plot([1,2])
plt.ylabel(network_training.history['val_acc'])
plt.show()
'''

test_list = valid_list
'''
### Generate predictions from trained model ###
for filename in test_list:
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)
'''
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 1024, 1024, 10)    100
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 1024, 1024, 2)     22
# =================================================================
# Total params: 3,012
# Trainable params: 2,932
# Non-trainable params: 80
# _________________________________________________________________
# Epoch 1/10
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2616: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2551: UserWarning: unpack: buffer size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# 50/50 [==============================] - 33s 659ms/step - loss: 1.1133 - accuracy: 0.6430 - val_loss: 2.0799 - val_accuracy: 0.6863
# Epoch 2/10
# 50/50 [==============================] - 29s 579ms/step - loss: 0.8868 - accuracy: 0.7825 - val_loss: 2.3822 - val_accuracy: 0.6835
# Epoch 3/10
# 50/50 [==============================] - 29s 589ms/step - loss: 0.7628 - accuracy: 0.8522 - val_loss: 1.3378 - val_accuracy: 0.6659
# Epoch 4/10
# 50/50 [==============================] - 28s 570ms/step - loss: 0.7343 - accuracy: 0.8635 - val_loss: 0.6905 - val_accuracy: 0.7138
# Epoch 5/10
# 50/50 [==============================] - 28s 568ms/step - loss: 0.8210 - accuracy: 0.8369 - val_loss: 0.6139 - val_accuracy: 0.8405
# Epoch 6/10
# 50/50 [==============================] - 28s 562ms/step - loss: 0.7056 - accuracy: 0.8844 - val_loss: 0.5263 - val_accuracy: 0.9338
# Epoch 7/10
# 50/50 [==============================] - 28s 560ms/step - loss: 0.7097 - accuracy: 0.8861 - val_loss: 0.4406 - val_accuracy: 0.9417
# Epoch 8/10
# 50/50 [==============================] - 28s 564ms/step - loss: 0.6497 - accuracy: 0.9104 - val_loss: 0.4401 - val_accuracy: 0.9525
# Epoch 9/10
# 50/50 [==============================] - 28s 568ms/step - loss: 0.6382 - accuracy: 0.9161 - val_loss: 0.4478 - val_accuracy: 0.9496
# Epoch 10/10
# 50/50 [==============================] - 27s 547ms/step - loss: 0.6342 - accuracy: 0.9183 - val_loss: 0.4483 - val_accuracy: 0.9587
# '\n### Generate predictions from trained model ###\nfor filename in test_list:\n    img,lbl = get_sample(filename,image_folder,label_folder)\n    lbl = np.argmax(lbl,axis=-1)\n    img = np.expand_dims(img,axis=0)\n    img = np.expand_dims(img,axis=-1)\n    img_pred = network.predict(img)\n    pred = np.argmax(img_pred[0,:,:,:],axis=-1)\n    matplotlib.image.imsave(prediction_folder+filename,pred)\n'

# %%
import numpy as np
import os
import random
from random import shuffle
import scipy.misc
import scipy
import time
import skimage.io
from skimage.io import imread
import keras
import keras.callbacks
from keras import optimizers, metrics, regularizers
from keras import backend as K
from keras.models import Sequential, Model, load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, SeparableConv2D, core
from keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose, Cropping2D, concatenate, Input
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.activations import softmax
import matplotlib
import sklearn.metrics
from sklearn.metrics import classification_report, confusion_matrix

class_weight_one = 1
class_weight_two = 1
batch_size = 2
epochs_2_train = 10
validPercent = 0.1
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
label_folder = '/data/Ro_ImageData/32xOTSU/' #Otsu images
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions2/' #Folder for predictions

def get_sample(sample, highSN_folder, lowSN_folder,label_folder):
    if ('_C' in sample):
    #If it's a low SN image
        inputImgPath = os.path.join(lowSN_folder, sample)
        maskImg = sample.split('_C')[0] + '.tiff'
    else:
    #If it's a high SN image
        inputImgPath = os.path.join(highSN_folder, sample)
        maskImg = sample
    maskImgPath = os.path.join(label_folder, maskImg)
    img_int = np.array(imread(inputImgPath), dtype = 'float32')/255
    lbl_int = np.array(imread(maskImgPath), dtype = 'float32')/2**16
    lbl_int[:,:,1] = 1-lbl_int[:,:,0]
    lbl_int = lbl_int[:,:,0:2]
    return img_int,lbl_int

def get_sample_test(sample,test_folder):
    img_int = np.array(imread(test_folder + sample), dtype = 'float32')/255
    return img_int

def data_generator(file_name_list,batch_size): #randomly sampled instances from file name list with batch size
    while True:
        batch_filenames = np.random.choice(file_name_list,batch_size)
        batch_input = []
        batch_output = []
        for i_filename in batch_filenames:
            Ai_img, Ai_mask = get_sample(i_filename,highSN_folder,lowSN_folder,label_folder)
            batch_input += [Ai_img]
            batch_output += [Ai_mask]
            #print(i_filename)
        batch_img = np.expand_dims(np.array(batch_input,dtype='float32'),axis=-1)
        batch_mask = np.array(batch_output,dtype='float32')
        yield (batch_img,batch_mask)

def Weighted_Binary_CrossEntropy(y_true_n,y_pred_n):
    b_ce = K.binary_crossentropy(y_true_n,y_pred_n)
    y_true = K.cast(K.expand_dims(K.argmax(y_true_n,axis=-1),axis=-1),dtype='float32')
    y_pred = K.cast(K.expand_dims(K.argmax(y_pred_n,axis=-1),axis=-1),dtype='float32')
    #Pixel Disparity
    one_weight = class_weight_one
    zero_weight = class_weight_two
    weight_vector = y_true * one_weight + (1.-y_true)*zero_weight
    weighted_b_ce = weight_vector*b_ce
    return K.mean(weighted_b_ce)

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    sampleList = []
    highSN = os.listdir(highSN_folder)
    #highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    #lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = list(np.random.choice(highSN,sampleSize-round(sampleSize*prop)))
    lowSample = list(np.random.choice(lowSN,round(sampleSize*prop)))
    sampleListAll = highSample + lowSample
    for file in sampleListAll:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.05)

indexes_valid = random.sample(range(0,len(sampleList)),int(validPercent*float(len(sampleList))))
indexes_train = [x for x in range(0,len(sampleList)) if x not in indexes_valid]
training_list = [x for ind,x in enumerate(sampleList) if ind in indexes_train]
valid_list = [x for ind,x in enumerate(sampleList) if ind in indexes_valid]
#(batch1,batch2) = data_generator(training_list,batch_size)
#print(batch1.shape)
#print(batch2.shape)

'''

test1,test2 = get_sample(training_list[0])
print(np.max(test2))
print(np.min(test2))
matplotlib.image.imsave('test1.png',test1)
matplotlib.image.imsave('test2.png',test2)

'''
num_train_calls = int(float(len(training_list)+1)/float(batch_size))
num_valid_calls = int(float(len(valid_list)+1)/float(batch_size))

#### Network is built ####
network = Sequential()
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),input_shape = (1024,1024,1),
padding = 'same'))
network.add(keras.layers.BatchNormalization())
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(10,(3,3),activation = 'relu',kernel_regularizer = regularizers.l2(.01),padding='same'))
network.add(keras.layers.BatchNormalization())
network.add(Dropout(0.25))
network.add(Conv2D(2,(1,1),activation = 'softmax',kernel_regularizer = regularizers.l2(.01),padding='same'))
sgd = optimizers.SGD(lr = 0.0001, decay = 1e-8, momentum = 0.9, nesterov = False)
network.compile(loss = Weighted_Binary_CrossEntropy, optimizer = sgd, metrics = ['accuracy'])
network.summary()
#network.load_weights('weights.h5')
network_training = network.fit_generator(data_generator(training_list,batch_size),steps_per_epoch = 50, 
                                         epochs = epochs_2_train, verbose = 1,validation_data = data_generator(valid_list,batch_size),
                                         validation_steps = num_valid_calls)
#network.save_weights('weights.h5')
TP = 0 #True Positives
TN = 0 #True Negatives
FP = 0 #False Positives
FN = 0 #False Negatives

for filename in valid_list: #Use for new lists
    
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    TP += np.sum(pred*lbl,dtype='float32')
    TN += np.sum((1-pred)*(1-lbl),dtype='float32')
    FP += np.sum((1-pred)*lbl,dtype='float32')
    FN += np.sum(pred*(1-lbl),dtype='float32')

ACC = (TP + TN)/(TP + TN + FP + FN) #Accuracy
Recall = (TP)/(TP + FN)
Precision = (TP)/(TP + FP)
MCC = ((TP * TN) - (FP * FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

np.savetxt('ValidationMetrics2.txt',(ACC,Recall,Precision,MCC))
np.savetxt('ValidationLoss2.txt',network_training.history['val_loss'])
np.savetxt('ValidationAcc2.txt',network_training.history['val_accuracy'])

'''
plt.plot([1,2])
plt.ylabel(network_training.history['val_acc'])
plt.show()
'''

test_list = valid_list
'''
### Generate predictions from trained model ###
for filename in test_list:
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)
'''
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 1024, 1024, 10)    100
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1024, 1024, 10)    910
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024, 1024, 10)    40
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024, 1024, 10)    0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1024, 1024, 2)     22
# =================================================================
# Total params: 3,012
# Trainable params: 2,932
# Non-trainable params: 80
# _________________________________________________________________
# Epoch 1/10
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2616: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /opt/conda/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2551: UserWarning: unpack: buffer size must be a multiple of element size
#   warnings.warn("unpack: %s" % e)
# 50/50 [==============================] - 39s 770ms/step - loss: 1.1566 - accuracy: 0.6341 - val_loss: 0.9175 - val_accuracy: 0.6792
# Epoch 2/10
# 50/50 [==============================] - 30s 602ms/step - loss: 0.9511 - accuracy: 0.7613 - val_loss: 0.8892 - val_accuracy: 0.6693
# Epoch 3/10
# 50/50 [==============================] - 24s 477ms/step - loss: 0.8602 - accuracy: 0.8202 - val_loss: 0.9473 - val_accuracy: 0.6884
# Epoch 4/10
# 50/50 [==============================] - 27s 541ms/step - loss: 0.7313 - accuracy: 0.8848 - val_loss: 0.8994 - val_accuracy: 0.7035
# Epoch 5/10
# 50/50 [==============================] - 27s 547ms/step - loss: 0.7051 - accuracy: 0.8978 - val_loss: 0.7456 - val_accuracy: 0.7262
# Epoch 6/10
# 50/50 [==============================] - 27s 547ms/step - loss: 0.6716 - accuracy: 0.9161 - val_loss: 0.6415 - val_accuracy: 0.8582
# Epoch 7/10
# 50/50 [==============================] - 28s 552ms/step - loss: 0.6622 - accuracy: 0.9144 - val_loss: 1.1458 - val_accuracy: 0.9389
# Epoch 8/10
# 50/50 [==============================] - 28s 552ms/step - loss: 0.6604 - accuracy: 0.9166 - val_loss: 0.4904 - val_accuracy: 0.9506
# Epoch 9/10
# 50/50 [==============================] - 27s 538ms/step - loss: 0.6871 - accuracy: 0.9090 - val_loss: 0.4709 - val_accuracy: 0.9422
# Epoch 10/10
# 50/50 [==============================] - 27s 549ms/step - loss: 0.6380 - accuracy: 0.9230 - val_loss: 0.4580 - val_accuracy: 0.9457
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c905f071fb04> in <module>
#     152 for filename in valid_list: #Use for new lists
#     153
# --> 154     img,lbl = get_sample(filename,image_folder,label_folder)
#     155     lbl = np.argmax(lbl,axis=-1)
#     156     img = np.expand_dims(img,axis=0)
#
# TypeError: get_sample() missing 1 required positional argument: 'label_folder'

# %%
prediction_folder = '/home/dspuser/MA499/Predictions/' #Folder for predictions
test_list = valid_list
for filename in test_list:
    img,lbl = get_sample(filename,image_folder,label_folder)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = network.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)

# %%
image_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/' #Source of images
label_folder = '/data/Ro_ImageData/32xOTSU/' #Otsu images
highSN_folder = '/data/Ro_ImageData/High SN ratio ceramic images/'
lowSN_folder = '/data/Ro_ImageData/Low SN ratio ceramic images/'
prediction_folder = '/home/dspuser/MA499/Predictions/' #Folder for predictions

'''
sampleListAll = os.listdir(image_folder)

for file in sampleListAll:
    if os.path.splitext(file)[1] == '.tiff':
        sampleList.append(file)
'''

def makeSampleList(highSN_folder,lowSN_folder,sampleSize,prop):
    sampleList = []
    highSN = os.listdir(highSN_folder)
    highSN = [os.path.join(highSN_folder,file) for file in highSN]
    lowSN = os.listdir(lowSN_folder)
    lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
    highSample = list(np.random.choice(highSN,sampleSize-round(sampleSize*prop)))
    lowSample = list(np.random.choice(lowSN,round(sampleSize*prop)))
    sampleListAll = highSample + lowSample
    for file in sampleListAll:
        if os.path.splitext(file)[1] == '.tiff':
            sampleList.append(file)
    return sampleList

sampleList = makeSampleList(highSN_folder,lowSN_folder,2000,0.9)

# %%
highSN = os.listdir(highSN_folder)
highSN = [os.path.join(highSN_folder,file) for file in highSN]
lowSN = os.listdir(lowSN_folder)
lowSN = [os.path.join(lowSN_folder,file) for file in lowSN]
highSample = list(np.random.choice(highSN,2000-round(2000*0.025)))
lowSample = list(np.random.choice(lowSN,round(2000*0.025)))

# %%
os.path.splitext(sampleList[1])[1]
# Out:
# '.tiff'

# %%
sampleList
# Out:
# ['/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r035_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c029.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r006_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c015.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c021.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c036.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c007.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r018_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c027.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r000_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r023_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c002.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c000.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c039.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c023.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r017_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r047_c044.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r004_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c026.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r045_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r021_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c038.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r041_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c003.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r003_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c014.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c041.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r022_c016.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c017.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c030.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r025_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r020_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c043.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r036_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c037.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r033_c034.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r026_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r008_c022.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r044_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c035.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r046_c012.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r029_c032.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r005_c047.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c033.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r014_c028.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c045.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r012_c024.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r001_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r007_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r010_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r031_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r024_c010.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r015_c011.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c001.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r013_c025.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r042_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r032_c013.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c040.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r037_c020.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r016_c042.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r028_c009.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r002_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r039_c046.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r011_c018.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r043_c005.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r009_c006.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r030_c031.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r038_c004.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r040_c008.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r027_c019.tiff',
#  '/data/Ro_ImageData/High SN ratio ceramic images/Tile_r034_c029.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c018_C.tiff',
# ...
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c042_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r010_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r011_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c001_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r034_c027_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c023_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r002_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c022_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r036_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r022_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r012_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c006_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r024_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r040_c019_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c030_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c000_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r032_c043_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c021_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r017_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r006_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c025_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r018_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r001_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c004_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r016_c005_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r029_c044_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r026_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r015_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r007_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r023_c014_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r033_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r042_c011_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c031_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r028_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c013_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r041_c024_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c041_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c034_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r039_c028_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r043_c033_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r027_c002_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c016_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r044_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c007_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c008_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c037_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r035_c009_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r004_c020_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r020_c026_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r014_c038_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r003_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c040_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r005_c018_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r021_c036_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r013_c035_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r038_c032_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r030_c010_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r019_c012_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r031_c017_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r025_c039_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r008_c015_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r000_c029_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r009_c003_C.tiff',
#  '/data/Ro_ImageData/Low SN ratio ceramic images/Tile_r037_c000_C.tiff',
#  ...]

# %%
ACC = (TP + TN)/(TP + TN + FP + FN) #Accuracy
Recall = (TP)/(TP + FN)
Precision = (TP)/(TP + FP)
MCC = ((TP * TN) - (FP * FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

np.savetxt('ValidationMetrics2.txt',(ACC,Recall,Precision,MCC))
np.savetxt('ValidationLoss2.txt',network_training.history['val_loss'])
np.savetxt('ValidationAcc2.txt',network_training.history['val_accuracy'])
test_list = valid_list
network.save("H95_L5.h5") 
model = keras.models.load_model("H95_L5.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3e878683b23a> in <module>
#       9 test_list = valid_list
#      10 network.save("H95_L5.h5")
# ---> 11 model = keras.models.load_model("H95_L5.h5")
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     367                       weighted_metrics=weighted_metrics,
#     368                       loss_weights=loss_weights,
# --> 369                       sample_weight_mode=sample_weight_mode)
#     370
#     371         # Set optimizer weights.
#
# /opt/conda/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in symbolic_fn_wrapper(*args, **kwargs)
#      73         if _SYMBOLIC_SCOPE.value:
#      74             with get_graph().as_default():
# ---> 75                 return func(*args, **kwargs)
#      76         else:
#      77             return func(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#     117         # Prepare list of loss functions, same size as model outputs.
#     118         self.loss_functions = training_utils.prepare_loss_functions(
# --> 119             self.loss, self.output_names)
#     120
#     121         self._feed_outputs = []
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training_utils.py in prepare_loss_functions(loss, output_names)
#     820             loss_functions.append(get_loss_function(loss.get(name, None)))
#     821     elif isinstance(loss, six.string_types):
# --> 822         loss_functions = [get_loss_function(loss) for _ in output_names]
#     823     elif isinstance(loss, collections.Sequence):
#     824         if len(loss) != len(output_names):
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training_utils.py in <listcomp>(.0)
#     820             loss_functions.append(get_loss_function(loss.get(name, None)))
#     821     elif isinstance(loss, six.string_types):
# --> 822         loss_functions = [get_loss_function(loss) for _ in output_names]
#     823     elif isinstance(loss, collections.Sequence):
#     824         if len(loss) != len(output_names):
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training_utils.py in get_loss_function(loss)
#     703     # Wrap loss function with signature `(y_true, y_pred, **kwargs)`
#     704     # in `LossFunctionWrapper` class.
# --> 705     loss_fn = losses.get(loss)
#     706
#     707     # For losses which are given as strings/functions in the compile API,
#
# /opt/conda/lib/python3.7/site-packages/keras/losses.py in get(identifier)
#     793     if isinstance(identifier, six.string_types):
#     794         identifier = str(identifier)
# --> 795         return deserialize(identifier)
#     796     if isinstance(identifier, dict):
#     797         return deserialize(identifier)
#
# /opt/conda/lib/python3.7/site-packages/keras/losses.py in deserialize(name, custom_objects)
#     774                                     module_objects=globals(),
#     775                                     custom_objects=custom_objects,
# --> 776                                     printable_module_name='loss function')
#     777
#     778
#
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     165             if fn is None:
#     166                 raise ValueError('Unknown ' + printable_module_name +
# --> 167                                  ':' + function_name)
#     168         return fn
#     169     else:
#
# ValueError: Unknown loss function:Weighted_Binary_CrossEntropy

# %%
def Weighted_Binary_CrossEntropy(y_true_n,y_pred_n):
    b_ce = K.binary_crossentropy(y_true_n,y_pred_n)
    y_true = K.cast(K.expand_dims(K.argmax(y_true_n,axis=-1),axis=-1),dtype='float32')
    y_pred = K.cast(K.expand_dims(K.argmax(y_pred_n,axis=-1),axis=-1),dtype='float32')
    #Pixel Disparity
    one_weight = class_weight_one
    zero_weight = class_weight_two
    weight_vector = y_true * one_weight + (1.-y_true)*zero_weight
    weighted_b_ce = weight_vector*b_ce
    return K.mean(weighted_b_ce)

# %%
### Generate predictions from trained model ###
for filename in test_list:
    img,lbl = get_sample(filename, highSN_folder, lowSN_folder, highSN_label, lowSN_label)
    lbl = np.argmax(lbl,axis=-1)
    img = np.expand_dims(img,axis=0)
    img = np.expand_dims(img,axis=-1)
    img_pred = model.predict(img)
    pred = np.argmax(img_pred[0,:,:,:],axis=-1)
    matplotlib.image.imsave(prediction_folder+filename,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c8e0dab262b5> in <module>
#       1 ### Generate predictions from trained model ###
#       2 for filename in test_list:
# ----> 3     img,lbl = get_sample(filename, highSN_folder, lowSN_folder, highSN_label, lowSN_label)
#       4     lbl = np.argmax(lbl,axis=-1)
#       5     img = np.expand_dims(img,axis=0)
#
# NameError: name 'highSN_label' is not defined
